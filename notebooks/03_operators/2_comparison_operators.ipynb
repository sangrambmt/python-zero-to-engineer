# %% [markdown]
# # Comparison Operators

# %% [markdown]
# ## 1. Problem
#
# Why does Python sometimes compare values that look the same but behave differently?

# %%
a = 10
b = 20

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)

# %% [markdown]
# ## 2. Mental Model
#
# - Comparison returns Boolean (True/False)
# - Used in decision making
# - Works across types (sometimes unexpectedly)

# %% [markdown]
# ## 3. Internal Mechanics

# %%
import dis

def compare(a, b):
    return a > b

dis.dis(compare)

# %% [markdown]
# ## 4. Edge Cases

# %%
print(10 == "10")   # False
print(10 == 10.0)   # True

# print(10 > "5")   # TypeError in Python 3

# %% [markdown]
# ## 5. Performance Thinking
#
# - Comparisons are O(1)
# - But string comparisons depend on length

# %% [markdown]
# ## 6. Real Use Case

# %%
score = 85

if score >= 90:
    print("Grade A")
elif score >= 75:
    print("Grade B")
else:
    print("Grade C")

# %% [markdown]
# ## 7. Anti-Pattern

# %%
# BAD
if x == True:
    pass

# GOOD
if x:
    pass

# %% [markdown]
# ## 8. Interview Signals
#
# - Difference between == and is
# - Comparing different types
# - Float vs int comparison

# %% [markdown]
# ## 9. Exercise

# %%
# Check if a number is between 10 and 50
x = 35

# Write condition below
