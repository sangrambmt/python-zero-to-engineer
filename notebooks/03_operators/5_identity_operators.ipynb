# %% [markdown]
# # Identity Operators

# %% [markdown]
# ## 1. Problem
#
# Why do two equal values sometimes not share the same identity?

# %%
a = [1, 2]
b = a
c = [1, 2]

print(a is b)
print(a is c)
print(a == c)
# Out:
# True
# False
# True

# %% [markdown]
# ## 2. Mental Model
#
# - `is` checks memory identity
# - `==` checks value equality
# - Same value ≠ same object

# %% [markdown]
# ## 3. Internal Mechanics

# %%
a = [1, 2]
b = a

print(id(a))
print(id(b))
# Out:
# 4383803072
# 4383803072

# %% [markdown]
# Same memory reference.

# %%
c = [1, 2]
print(id(c))
# Out:
# 4383781248

# %% [markdown]
# Different object, same value.

# %% [markdown]
# ## 4. Edge Cases

# %%
x = 256
y = 256

print(x is y)  # often True (cached)

x = 1000
y = 1000

print(x is y)  # often False
# Out:
# True
# False

# %% [markdown]
# Small integers may be cached by Python.

# %% [markdown]
# ## 5. Performance Thinking
#
# - `is` is faster than `==`
# - But only use for identity checks

# %% [markdown]
# ## 6. Real Use Case

# %%
value = None

if value is None:
    print("No value")
# Out:
# No value

# %% [markdown]
# `is None` is the correct pattern.

# %% [markdown]
# ## 7. Anti-Pattern

# %%
# BAD
x = 1000
y = 1000

print(x is y)  # unreliable

# GOOD
print(x == y)
# Out:
# False
# True

# %% [markdown]
# ## 8. Interview Signals
#
# - Difference between `is` and `==`
# - Why integer caching exists
# - When to use `is None`

# %% [markdown]
# ## 9. Exercise

# %%
# Fix the bug
value = None

if value == None:
    print("Fix this condition")
# Out:
# Fix this condition
